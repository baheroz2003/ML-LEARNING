# %%
import pandas as pd
import numpy as np
iris=pd.read_csv("http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data")
print(type(iris))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# <!-- pandas is useful for data processing and analysis
# pandas dataframe is two dimensional tabular data structure with labelled axes(rows and columns) -->
# <!-- we can also use excel file -->
# df.isnull().sum():will tell you about the no of  missing values
# count():is used to count the no of values

# %%
df=iris.copy()

# %%
df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
print(df.shape)
# Out:
# (149, 5)

# %%
df.columns
# Out:
# Index(['5.1', '3.5', '1.4', '0.2', 'Iris-setosa'], dtype='object')

# %%
df.columns=['sl','sw','pl','pw','flower_type']

# %%
print(df.shape)
# Out:
# (149, 5)

# %%
df.describe()
# Out:
#                s1          sw          pl          pw
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
df.sl
# Out:
# 0      4.9
# 1      4.7
# 2      4.6
# 3      5.0
# 4      5.4
#       ...
# 144    6.7
# 145    6.3
# 146    6.5
# 147    6.2
# 148    5.9
# Name: sl, Length: 149, dtype: float64

# %%
df.isnull()
# Out:
#         sl     sw     pl     pw  flower_type
# 0    False  False  False  False        False
# 1    False  False  False  False        False
# 2    False  False  False  False        False
# 3    False  False  False  False        False
# 4    False  False  False  False        False
# ..     ...    ...    ...    ...          ...
# 144  False  False  False  False        False
# 145  False  False  False  False        False
# 146  False  False  False  False        False
# 147  False  False  False  False        False
# 148  False  False  False  False        False
#
# [149 rows x 5 columns]

# %%
df.isnull()
# Out:
#         sl     sw     pl     pw  flower_type
# 0    False  False  False  False        False
# 1    False  False  False  False        False
# 2    False  False  False  False        False
# 3    False  False  False  False        False
# 4    False  False  False  False        False
# ..     ...    ...    ...    ...          ...
# 144  False  False  False  False        False
# 145  False  False  False  False        False
# 146  False  False  False  False        False
# 147  False  False  False  False        False
# 148  False  False  False  False        False
#
# [149 rows x 5 columns]

# %%
df.iloc[1:4,2:3] #rows 1-3
#col 2
# Out:
#    1.4
# 1  1.3
# 2  1.5
# 3  1.4

# %%
#it will delete 0 wala
a=df.drop(0)
a.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa

# %%
#it takes cable not the column
df.drop(3,inplace=True)
df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa

# %%
df.index
# Out:
# Index([  0,   1,   2,   4,   5,   6,   7,   8,   9,  10,
#        ...
#        139, 140, 141, 142, 143, 144, 145, 146, 147, 148],
#       dtype='int64', length=148)

# %%
#use df.index to remove
#index mtlb jo hai uske reference me baat hogi

# %%
df[df.sl>5]
# Out:
#       sl   sw   pl   pw     flower_type
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# 9    5.4  3.7  1.5  0.2     Iris-setosa
# 13   5.8  4.0  1.2  0.2     Iris-setosa
# 14   5.7  4.4  1.5  0.4     Iris-setosa
# 15   5.4  3.9  1.3  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [117 rows x 5 columns]

# %%
cl=df[df.flower_type=='Iris-setosa']
cl.describe()
# Out:
#               sl         sw         pl         pw
# count  49.000000  49.000000  49.000000  49.000000
# mean    5.004082   3.416327   1.465306   0.244898
# std     0.355879   0.384787   0.175061   0.108130
# min     4.300000   2.300000   1.000000   0.100000
# 25%     4.800000   3.100000   1.400000   0.200000
# 50%     5.000000   3.400000   1.500000   0.200000
# 75%     5.200000   3.700000   1.600000   0.300000
# max     5.800000   4.400000   1.900000   0.600000

# %%
print(df.head())
print(df.iloc[0])
print(df.loc[0])
# Out:
#     sl   sw   pl   pw  flower_type
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# sl                     4.9
# sw                     3.0
# pl                     1.4
# pw                     0.2
# flower_type    Iris-setosa
# Name: 0, dtype: object
# sl                     4.9
# sw                     3.0
# pl                     1.4
# pw                     0.2
# flower_type    Iris-setosa
# Name: 0, dtype: object

# %%
#add a row
df.loc[0]=[1,2,3,4,"Iris-setosa"]

# %%
df.head()
# Out:
#     sl   sw   pl   pw  flower_type
# 0  1.0  2.0  3.0  4.0  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
df.loc[149]=[1,2,3,4,"Iris-setosa"]

# %%
df.tail()
# Out:
#       sl   sw   pl   pw     flower_type
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
# 149  1.0  2.0  3.0  4.0     Iris-setosa

# %%
df.reset_index()
#index column will not be there if u use drop
df.reset_index(drop=True,inplace=True)
df.index
# Out:
# RangeIndex(start=0, stop=149, step=1)

# %%
#delete column axis 0 for deleting row
df.drop('sl',axis=1)
# Out:
#       sw   pl   pw     flower_type
# 0    3.0  1.4  0.2     Iris-setosa
# 1    3.2  1.3  0.2     Iris-setosa
# 2    3.1  1.5  0.2     Iris-setosa
# 3    3.6  1.4  0.2     Iris-setosa
# 4    3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...             ...
# 144  3.0  5.2  2.3  Iris-virginica
# 145  2.5  5.0  1.9  Iris-virginica
# 146  3.0  5.2  2.0  Iris-virginica
# 147  3.4  5.4  2.3  Iris-virginica
# 148  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 4 columns]

# %%
df.describe()
# Out:
#                sl          sw          pl          pw
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
#using del keyword is better
del df['sw']

# %%
df.describe()
df.head()
# Out:
#     sl   pl   pw  flower_type
# 0  4.9  1.4  0.2  Iris-setosa
# 1  4.7  1.3  0.2  Iris-setosa
# 2  4.6  1.5  0.2  Iris-setosa
# 3  5.0  1.4  0.2  Iris-setosa
# 4  5.4  1.7  0.4  Iris-setosa

# %%
#to get our all data back
df=iris.copy()
df.columns=['sl','sw','pl','pw','flower_type']
df.describe()
# Out:
#                sl          sw          pl          pw
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
#to add a column which is difference of two columns pl-pw
df["diff_pl_pw"]=df["pl"]-df["pw"]
df.tail()
# Out:
#       sl   sw   pl   pw     flower_type  diff_pl_pw
# 144  6.7  3.0  5.2  2.3  Iris-virginica         2.9
# 145  6.3  2.5  5.0  1.9  Iris-virginica         3.1
# 146  6.5  3.0  5.2  2.0  Iris-virginica         3.2
# 147  6.2  3.4  5.4  2.3  Iris-virginica         3.1
# 148  5.9  3.0  5.1  1.8  Iris-virginica         3.3

# %%
#jb apne pass na value ho toh kya kre
# df.iloc[:0]#first column
df.iloc[2:4,1:3]=np.nan
df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  NaN  NaN  0.2  Iris-setosa
# 3  5.0  NaN  NaN  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
df.describe()
# Out:
#               5.1         3.5         1.4         0.2
# count  149.000000  147.000000  147.000000  149.000000
# mean     5.848322    3.046939    3.806122    1.205369
# std      0.828594    0.434048    1.750351    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa
# 6  5.0  3.4  1.5  0.2  Iris-setosa

# %%
#sometime we don't want to delete na values rather fill up with other values
df.sw.fillna(df.sw.mean(),inplace=True)
#for every column we can do the same
# Out:
# <ipython-input-16-50305aad8fe9>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.sw.fillna(df.sw.mean(),inplace=True)

# %%
df.sw.fillna(df.sw.mean())
df.head()
# Out:
#     sl   sw   pl   pw  flower_type
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa
# 6  5.0  3.4  1.5  0.2  Iris-setosa

# %%
df['Gender']='Female'
df.head()
df.iloc[0:3,5]='Male'
df.head()
def f(s):
  if s=='Male':
      return 0
  else:
      return 1
df["sex"]=df.Gender.apply(f)
df.head()
#-ve correlated and +ve correlated 
#if value increase due to whichothervalue decreases then -ve if increases then +ve
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa  Gender  sex
# 0  4.9  3.0  1.4  0.2         Male    Male    0
# 1  4.7  3.2  1.3  0.2         Male    Male    0
# 2  4.6  3.1  1.5  0.2         Male    Male    0
# 3  5.0  3.6  1.4  0.2  Iris-setosa  Female    1
# 4  5.4  3.9  1.7  0.4  Iris-setosa  Female    1
