# %%
#ML PROJECT WORKFLOW
#DATA-DATA PRE-PROCESSING-DATA ANALYSIS-TRAIN TEST SPLIT-MACHINE LEARNING MODEL

# %%
#80 we used for training and 20 for testing
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
#steps 1 load the dataset
#steps 2 in outcome section 0 is for non-diabetic and 1 for diabetic
#steps 3 seprating the data and labels
#steps 4 after that data standarizaion
#splitting the data into training data and testing data

# %%
#handling imbalanced dataset-a dataset with an unequal class distribution
credit_card_data=pd.read_csv('credit_data.csv')

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 11954  20631  1.504204 -0.411728  0.200090 -0.778753 -0.442232 -0.119677
# 11955  20636  1.134994  0.096340  0.277921  0.319692  0.742800  1.611803
# 11956  20638 -6.305012  3.944886 -4.707362  1.539602 -3.934785 -1.730565
# 11957  20638  1.161960 -0.398297  1.123732 -0.474237 -1.226667 -0.519325
# 11958  20642  1.291096 -0.226628  0.708386 -0.719236 -0.659099 -0.273757
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 11954 -0.782660 -0.165178  0.691819  ... -0.136231 -0.217274 -0.143260
# 11955 -0.458649  0.390012  1.424541  ... -0.395605 -0.743542  0.222256
# 11956 -2.104936  3.843447  0.863458  ...  0.073140 -0.039935 -0.108896
# 11957 -0.804179  0.070134  3.262926  ... -0.121191  0.097255  0.050903
# 11958 -0.612042 -0.111488  3.032258  ...       NaN       NaN       NaN
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
#distribution of two classes
credit_card_data['Class'].value_counts()
#0 for legit 1 for not legit
#due to uneven distribution it is highly imbalanced
# Out:
# Class
# 0.0    11906
# 1.0       52
# Name: count, dtype: int64

# %%
#seperating the legit and fraudlent transactions
legit=credit_card_data[credit_card_data.Class==0]
fraud=credit_card_data[credit_card_data.Class==1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (11906, 31)
# (52, 31)

# %%
#under-sampling
legit_sample=legit.sample(n=52)

# %%
legit_sample.shape
# Out:
# (52, 31)

# %%
#concatenate the two data frame
new_dataset=pd.concat([legit_sample,fraud],axis=0)
#one top of other with axis=0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
#loading the data from csv file to a pandas dataframe
diabetes_dataset=pd.read_csv('diabetes.csv')

# %%
diabetes_dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_dataset.shape
# Out:
# (768, 9)

# %%
diabetes_dataset.describe()
#0 for non diabetic
#1 for diabetic
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
#seperating features and target
#axis 0 fro dropping row and 1 for dropping column
X=diabetes_dataset.drop(columns='Outcome',axis=1)
Y=diabetes_dataset['Outcome']

# %%
print(X)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
print(Y)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
#data standarisation
scaler=StandardScaler()
# scaler.fit_tansform(X)

# %%
scaler.fit_transform(X)
# Out:
# array([[ 0.63994726,  0.84832379,  0.14964075, ...,  0.20401277,
#          0.46849198,  1.4259954 ],
#        [-0.84488505, -1.12339636, -0.16054575, ..., -0.68442195,
#         -0.36506078, -0.19067191],
#        [ 1.23388019,  1.94372388, -0.26394125, ..., -1.10325546,
#          0.60439732, -0.10558415],
#        ...,
#        [ 0.3429808 ,  0.00330087,  0.14964075, ..., -0.73518964,
#         -0.68519336, -0.27575966],
#        [-0.84488505,  0.1597866 , -0.47073225, ..., -0.24020459,
#         -0.37110101,  1.17073215],
#        [-0.84488505, -0.8730192 ,  0.04624525, ..., -0.20212881,
#         -0.47378505, -0.87137393]])

# %%
X=standarized_data=scaler.fit_transform(X)

# %%
#splitting the data into training data and testing data
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8)

# %%
#TEXT DATA PRE PROCESSING:
#POINTS 1 :WHENVER THE DATA SIZE IS LARGE USE IT THROUGH GOOGLE DRIVE
#importing the dependices:to convert text data into numerial data
import numpy as np
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
#load the data to a pandas dataframe
news_dataset=pd.read_csv('train.csv')

# %%
#first 5 rows of the dataset
news_dataset.head()
#0 for real news and 1 for fake news
#more the data better you performance will be

# %%
#checking for missing values
news_dataset.isnull().sum()

# %%
#replacing the missing value with null string
news_dataset=news_dataset.fillna('')

# %%
#merging the eauthor name and news title
news_dataset['content']=news_dataset['author']+' '+news_dataset['title']

# %%
#seperating feature and target
X=news_dataset.drop(columns='label',axis=1)
Y=news_dataset['label']

# %%
#stemming is the process of reducing a word to its Root Word

# %%
port_stem=PorterStemmer()

# %%
def steming(content):
  #if we only want atoz or A to Z
  stemmed_content=re.sub('[^a-zA-Z]',' ',content)
  #if we want lower
  stemmed_content=stemmed_content.lower()
  stemmed_content=stemmed_content.split()
  stemmed_content=[port_stem.stem(word) for word in stemmed_content if not word in stopwords.words('english')]
  stemmed_content=' '.join(stemmed_content)
  return stemmed_content

# %%
news_dataset['content']=news_dataset['content'].apply(stemming)

# %%
X=news_dataset['content'].values
Y=news_data['label'].values

# %%
Y.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-de29cf719ad1> in <cell line: 1>()
# ----> 1 Y.shape
#
# NameError: name 'Y' is not defined

# %%
#converting the textual data to feature vectors
vectorizer=TfidfVectorizer()
vectorizer.fit(X)
X=vectorizer.transform(X)
#you can print and check
